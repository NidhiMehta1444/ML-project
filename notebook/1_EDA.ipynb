# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv('data/raw.csv')

# %%
df.head()
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic_group  age  english_grade  math_grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences_grade  language_grade  portfolio_rating  coverletter_rating  \
# ...

# %% [markdown]
# Shape of the dataset

# %%
df.shape
# Out:
# (307, 16)

# %% [markdown]
# Dataset Information
# gender: sex of students(M/F)
# name: name of students
# city: city of students
# age: age of students
# english score
# math score
# science score

# %% [markdown]
# Data checks to perform

# %% [markdown]
# -check missing values
# -check duplicates
# -check data type
# -check the number of unique values of each column
# -check statistics of data set
# -check various categories present in the different categorical column

# %% [markdown]
# Check missing values

# %%
df.isna().sum()
# Out:
# id                      0
# name                    0
# nationality             0
# city                    0
# latitude                0
# longitude               0
# gender                  0
# ethnic_group          307
# age                     0
# english_grade           0
# math_grade              0
# sciences_grade          0
# language_grade          0
# portfolio_rating        0
# coverletter_rating      0
# refletter_rating        0
# dtype: int64

# %% [markdown]
# There are no missing values in the data set

# %% [markdown]
# Check Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are no duplicated values in the data set

# %% [markdown]
# Check data types

# %%
#check null and dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  307 non-null    int64
#  1   name                307 non-null    object
#  2   nationality         307 non-null    object
#  3   city                307 non-null    object
#  4   latitude            307 non-null    float64
#  5   longitude           307 non-null    float64
#  6   gender              307 non-null    object
#  7   ethnic_group        0 non-null      float64
#  8   age                 307 non-null    int64
#  9   english_grade       307 non-null    float64
#  10  math_grade          307 non-null    float64
#  11  sciences_grade      307 non-null    float64
#  12  language_grade      307 non-null    float64
#  13  portfolio_rating    307 non-null    float64
#  14  coverletter_rating  307 non-null    float64
# ...

# %% [markdown]
# Checking the number of unique values of each column

# %%
df.nunique()
# Out:
# id                    307
# name                  307
# nationality            31
# city                  161
# latitude              156
# longitude             158
# gender                  3
# ethnic_group            0
# age                     8
# english_grade          25
# math_grade             20
# sciences_grade         24
# language_grade          6
# portfolio_rating        5
# coverletter_rating      6
# refletter_rating        5
# dtype: int64

# %% [markdown]
# Check statistics of data set

# %%
df.describe()
# Out:
#                id    latitude   longitude  ethnic_group         age  \
# count  307.000000  307.000000  307.000000           0.0  307.000000
# mean   153.000000   32.863388  -64.539121           NaN   21.964169
# std     88.767487   13.498582   81.249146           NaN    1.248013
# min      0.000000  -33.450000 -123.130000           NaN   19.000000
# 25%     76.500000   32.720000 -118.240000           NaN   21.000000
# 50%    153.000000   34.390000  -99.140000           NaN   22.000000
# 75%    229.500000   38.960000  -73.855000           NaN   23.000000
# max    306.000000   59.890000  139.750000           NaN   26.000000
#
#        english_grade  math_grade  sciences_grade  language_grade  \
# count     307.000000  307.000000      307.000000      307.000000
# mean        3.369707    3.414332        3.446580        4.396417
# std         0.538724    0.476839        0.509081        0.996474
# min         1.500000    2.100000        1.400000        1.000000
# ...

# %% [markdown]
# Exploring Data

# %%
df.head()
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic_group  age  english_grade  math_grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences_grade  language_grade  portfolio_rating  coverletter_rating  \
# ...

# %%
print("Categories in 'gender' variable:   ",end=" " )
print(df['gender'].unique())

print("Categories in 'age' variable:   ",end=" " )
print(df['age'].unique())

print("Categories in 'language_grade' variable:   ",end=" " )
print(df['language_grade'].unique())
# Out:
# Categories in 'gender' variable:    ['F' 'M' 'other']
# Categories in 'age' variable:    [22 20 21 24 23 25 26 19]
# Categories in 'language_grade' variable:    [1.  5.  2.  3.  4.  3.7]

# %%
#define numerical & categorical columns

numeric_features=[feature for feature in df.columns if df[feature].dtype != '0']
categorical_features=[feature for feature in df.columns if df[feature].dtype == '0']

#print columns
print('We have {} numerical features : {}'.format(len(numeric_features),numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features),categorical_features))
# Out:
# We have 16 numerical features : ['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender', 'ethnic_group', 'age', 'english_grade', 'math_grade', 'sciences_grade', 'language_grade', 'portfolio_rating', 'coverletter_rating', 'refletter_rating']
#
# We have 0 categorical features : []

# %%
df.head(2)
# Out:
#    id            name               nationality           city  latitude  \
# 0   0       Kiana Lor                     China         Suzhou     31.31
# 1   1  Joshua Lonaker  United States of America  Santa Clarita     34.39
#
#    longitude gender  ethnic_group  age  english_grade  math_grade  \
# 0     120.62      F           NaN   22            3.5         3.7
# 1    -118.54      M           NaN   22            2.9         3.2
#
#    sciences_grade  language_grade  portfolio_rating  coverletter_rating  \
# 0             3.1             1.0               4.0                 4.0
# 1             3.6             5.0               5.0                 4.0
#
#    refletter_rating
# 0               4.0
# 1               5.0

# %% [markdown]
# Adding columns for "Total Score" and "Average"

# %%
df['total_score']=df['english_grade']+df['sciences_grade']+df['language_grade']
df['average']=df['total_score']/3
df.head()
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic_group  age  english_grade  math_grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences_grade  language_grade  portfolio_rating  coverletter_rating  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender',
#        'ethnic_group', 'age', 'english_grade', 'math_grade', 'sciences_grade',
#        'language_grade', 'portfolio_rating', 'coverletter_rating',
#        'refletter_rating', 'total_score', 'average'],
#       dtype='object')

# %%
language_grade=df[df['language_grade'] == 100]['average'].count()
portfolio_rating=df[df['portfolio_rating'] ==100]['average'].count()
math_full=df[df['math_grade'] == 100]['average'].count()

print(f'Number of students with full marks in Maths: {math_full}')
print(f'Number of students with full marks in Writing: {portfolio_rating}')
print(f'Number of students with full marks in language: {language_grade}')
# Out:
# Number of students with full marks in Maths: 0
# Number of students with full marks in Writing: 0
# Number of students with full marks in language: 0

# %% [markdown]
# Exploring Data (Visualization)

# %% [markdown]
# Visualize average score distribution to make some conclusion.

# %% [markdown]
# -Histogram
# -Kernel Distribution Function(KDE)

# %% [markdown]
# Histogram & KDE

# %%
fig, axs =plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='average',kde=True,hue='gender')
plt.show()

# %%
fig, axs =plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='total_score',kde=True,hue='gender')
plt.show()

# %% [markdown]
# Insights

# %% [markdown]
# Female students tend to perform well than male students.
