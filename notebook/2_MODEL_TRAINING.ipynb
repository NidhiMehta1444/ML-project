# %%
#Basic import

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Modelling
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
import warnings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 5
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
#       7 #Modelling
#
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\matplotlib\__init__.py:272
#     267         if parse_version(module.__version__) < parse_version(minver):
#     268             raise ImportError(f"Matplotlib requires {modname}>={minver}; "
#     269                               f"you have {module.__version__}")
# --> 272 _check_versions()
#     275 # The decorator ensures this always returns the same handler (and it is only
#     276 # attached once).
#     277 @functools.cache
#     278 def _ensure_handler():
#
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\matplotlib\__init__.py:266, in _check_versions()
#     257 from . import ft2font
#     259 for modname, minver in [
#     260         ("cycler", "0.10"),
#     261         ("dateutil", "2.7"),
#    (...)
#     264         ("pyparsing", "2.3.1"),
#     265 ]:
# --> 266     module = importlib.import_module(modname)
#     267     if parse_version(module.__version__) < parse_version(minver):
#     268         raise ImportError(f"Matplotlib requires {modname}>={minver}; "
#     269                           f"you have {module.__version__}")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\kiwisolver\__init__.py:8
#       1 # --------------------------------------------------------------------------------------
#       2 # Copyright (c) 2013-2024, Nucleic Development Team.
#       3 #
#    (...)
#       6 # The full license is in the file LICENSE, distributed with this software.
#       7 # --------------------------------------------------------------------------------------
# ----> 8 from ._cext import (
#       9     Constraint,
#      10     Expression,
#      11     Solver,
#      12     Term,
#      13     Variable,
#      14     __kiwi_version__,
#      15     __version__,
#      16     strength,
#      17 )
#      18 from .exceptions import (
#      19     BadRequiredStrength,
#      20     DuplicateConstraint,
#    (...)
#      24     UnsatisfiableConstraint,
#      25 )
#      27 __all__ = [
#      28     "BadRequiredStrength",
#      29     "DuplicateConstraint",
#    (...)
#      41     "__kiwi_version__",
#      42 ]
#
# ModuleNotFoundError: No module named 'kiwisolver._cext'

# %% [markdown]
# Import the CSV Data as Pandas DataFrame

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\Scripts\python.exe

# %%
import PIL
print(PIL.__version__)
# Out:
# 10.2.0

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3], [4,5,6])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 plt.plot([1,2,3], [4,5,6])
#       4 plt.show()
#
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\matplotlib\__init__.py:272
#     267         if parse_version(module.__version__) < parse_version(minver):
#     268             raise ImportError(f"Matplotlib requires {modname}>={minver}; "
#     269                               f"you have {module.__version__}")
# --> 272 _check_versions()
#     275 # The decorator ensures this always returns the same handler (and it is only
#     276 # attached once).
#     277 @functools.cache
#     278 def _ensure_handler():
#
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\matplotlib\__init__.py:266, in _check_versions()
#     257 from . import ft2font
#     259 for modname, minver in [
#     260         ("cycler", "0.10"),
#     261         ("dateutil", "2.7"),
#    (...)
#     264         ("pyparsing", "2.3.1"),
#     265 ]:
# --> 266     module = importlib.import_module(modname)
#     267     if parse_version(module.__version__) < parse_version(minver):
#     268         raise ImportError(f"Matplotlib requires {modname}>={minver}; "
#     269                           f"you have {module.__version__}")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\kiwisolver\__init__.py:8
#       1 # --------------------------------------------------------------------------------------
#       2 # Copyright (c) 2013-2024, Nucleic Development Team.
#       3 #
#    (...)
#       6 # The full license is in the file LICENSE, distributed with this software.
#       7 # --------------------------------------------------------------------------------------
# ----> 8 from ._cext import (
#       9     Constraint,
#      10     Expression,
#      11     Solver,
#      12     Term,
#      13     Variable,
#      14     __kiwi_version__,
#      15     __version__,
#      16     strength,
#      17 )
#      18 from .exceptions import (
#      19     BadRequiredStrength,
#      20     DuplicateConstraint,
#    (...)
#      24     UnsatisfiableConstraint,
#      25 )
#      27 __all__ = [
#      28     "BadRequiredStrength",
#      29     "DuplicateConstraint",
#    (...)
#      41     "__kiwi_version__",
#      42 ]
#
# ModuleNotFoundError: No module named 'kiwisolver._cext'

# %%
df= pd.read_csv('data/raw.csv')

# %%
df.head()
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic_group  age  english_grade  math_grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences_grade  language_grade  portfolio_rating  coverletter_rating  \
# 0             3.1             1.0               4.0                 4.0
# 1             3.6             5.0               5.0                 4.0
# 2             3.2             5.0               3.0                 3.0
# 3             3.2             5.0               5.0                 2.0
# 4             3.4             1.0               4.0                 4.0
#
#    refletter_rating
# 0               4.0
# 1               5.0
# 2               4.0
# 3               4.0
# 4               5.0

# %% [markdown]
# Preparing X and Y variables

# %%
X= df.drop(columns=['math_grade'],axis=1)

# %%
X.head()
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic_group  age  english_grade  \
# 0     31.31     120.62      F           NaN   22            3.5
# 1     34.39    -118.54      M           NaN   22            2.9
# 2     37.80    -122.27      F           NaN   22            3.9
# 3     37.69    -122.09      F           NaN   20            3.3
# 4    -23.18     -45.88      F           NaN   21            3.7
#
#    sciences_grade  language_grade  portfolio_rating  coverletter_rating  \
# 0             3.1             1.0               4.0                 4.0
# 1             3.6             5.0               5.0                 4.0
# 2             3.2             5.0               3.0                 3.0
# 3             3.2             5.0               5.0                 2.0
# 4             3.4             1.0               4.0                 4.0
#
#    refletter_rating
# 0               4.0
# 1               5.0
# 2               4.0
# 3               4.0
# 4               5.0

# %%
print("Categories in 'gender' variable:",end=" ")
print(df['gender'].unique())
# Out:
# Categories in 'gender' variable: ['F' 'M' 'other']

# %%
y=df['math_grade']

# %%
y
# Out:
# 0      3.7
# 1      3.2
# 2      3.8
# 3      2.8
# 4      2.6
#       ...
# 302    3.7
# 303    3.9
# 304    3.4
# 305    2.8
# 306    3.2
# Name: math_grade, Length: 307, dtype: float64

# %%
#Create transformer with 3 types of transformers

num_features=X.select_dtypes(exclude="object").columns
cat_features=X.select_dtypes(include="object").columns

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

nummeric_transformer=StandardScaler()
oh_transformer=OneHotEncoder()

preprocessor=ColumnTransformer(
    [
        ("OneHotEncoder",oh_transformer,cat_features),
        ("StandardScaler",nummeric_transformer,num_features),
    ]
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\scipy\__init__.py:114
#     113 try:
# --> 114     from scipy._lib._ccallback import LowLevelCallable
#     115 except ImportError as e:
#
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\scipy\_lib\_ccallback.py:1
# ----> 1 from . import _ccallback_c
#       3 import ctypes
#
# ImportError: cannot import name '_ccallback_c' from 'scipy._lib' (c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\scipy\_lib\__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 6
#       3 num_features=X.select_dtypes(exclude="object").columns
#       4 cat_features=X.select_dtypes(include="object").columns
# ----> 6 from sklearn.preprocessing import OneHotEncoder, StandardScaler
#       7 from sklearn.compose import ColumnTransformer
#       9 nummeric_transformer=StandardScaler()
#
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\sklearn\__init__.py:83
#      69     # We are not importing the rest of scikit-learn during the build
#      70     # process, as it may not be compiled yet
#      71 else:
#    (...)
#      77     # later is linked to the OpenMP runtime to make it possible to introspect
#      78     # it and importing it first would fail if the OpenMP dll cannot be found.
#      79     from . import (
#      80         __check_build,  # noqa: F401
#      81         _distributor_init,  # noqa: F401
#      82     )
# ---> 83     from .base import clone
#      84     from .utils._show_versions import show_versions
#      86     __all__ = [
#      87         "calibration",
#      88         "cluster",
#    (...)
#     129         "show_versions",
#     130     ]
#
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils import _IS_32BIT
#      20 from .utils._estimator_html_repr import estimator_html_repr
#      21 from .utils._metadata_requests import _MetadataRequester
#
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\sklearn\utils\__init__.py:15
#      12 from itertools import compress, islice
#      14 import numpy as np
# ---> 15 from scipy.sparse import issparse
#      17 from .. import get_config
#      18 from ..exceptions import DataConversionWarning
#
# File c:\Users\Nidhi Mehta\OneDrive\Desktop\ML Project\venv\lib\site-packages\scipy\__init__.py:119
#     115 except ImportError as e:
#     116     msg = "The `scipy` install you are using seems to be broken, " + \
#     117           "(extension modules cannot be imported), " + \
#     118           "please try reinstalling."
# --> 119     raise ImportError(msg) from e
#     122 from scipy._lib._testutils import PytestTester
#     123 test = PytestTester(__name__)
#
# ImportError: The `scipy` install you are using seems to be broken, (extension modules cannot be imported), please try reinstalling.
